# %%
import sys
sys.path.append('..')

# %%
from pathlib import Path
import dietrx
from dietrx import app
from dietrx import db
from dietrx.models import *

import pandas as pd

DATA = Path('../data/version-3/')

# %%
def add_to_db(obj, dl):
    for i, item in enumerate(dl):
        db.session.add(obj(**item))

        if (i+1) % 10000 == 0:
            db.session.commit()
    db.session.commit()
    
    
def remove_from_db(obj):
    for i, o in enumerate(obj.query.all()):
        db.session.delete(o)
        
        if (i+1) % 10000 == 0:
            db.session.commit()
            
    db.session.commit()

# %% [markdown]
# ### Delete previous data in DB

# %%
remove_from_db(Food_disease)
remove_from_db(Disease_gene)
remove_from_db(Food_gene)
remove_from_db(Food_chemical)
remove_from_db(Chemical_disease)
remove_from_db(Food)
remove_from_db(Disease)
remove_from_db(Gene)
remove_from_db(References)
remove_from_db(Chemical)

# %%
def clean_colnames(df):
    df.columns = [col.replace(' ', '-').lower() for col in df.columns]

# %% [markdown]
# ## A. Lexicons

# %% [markdown]
# ### Food Lexicon

# %%
df = pd.read_csv(DATA/'food-lexicon-automated.tsv', sep='\t', encoding='utf-8')
clean_colnames(df)

del df['foodb-group'], df['foodb-subgroup']
df.head()
# Out:
#                 common-names          food-id  food-category  \
# 0  alexanders; horse parsley   Plant ID:40962  Miscellaneous
# 1                        NaN  Plant ID:942083  Miscellaneous
# 2        dotted blazing star  Plant ID:344074  Miscellaneous
# 3              plymouth pear  Plant ID:761867  Miscellaneous
# 4                        NaN   Plant ID:49166  Miscellaneous
#
#                 food-name         scientific-name    tax-id
# 0              Alexanders      Smyrnium olusatrum   40962.0
# 1    Scrophularia umbrosa    Scrophularia umbrosa  942083.0
# 2     Dotted blazing star        Liatris punctata  344074.0
# 3           Plymouth pear           Pyrus cordata  761867.0
# 4  Rhododendron kaempferi  Rhododendron kaempferi   49166.0

# %%
# Replace NaN with None
df = df.where((pd.notnull(df)), None)

# Rename columns to match db schema.
df.rename(columns={
    'common-names': 'common_names',
    'food-name': 'display_name',
    'food-id': 'food_id',
    'food-category': 'food_category',
    'scientific-name': 'scientific_name',
    'tax-id':'tax_id',
}, inplace=True)

data_list= list(df.T.to_dict().values())

# %%
add_to_db(Food, data_list)

# %% [markdown]
# ### Disease Lexicon

# %%
df = pd.read_csv(DATA/'disease-lexicon.tsv', sep='\t', encoding='utf-8', index_col=0)
clean_colnames(df)
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#      disease-id                        disease-name  \
# 0  MESH:D008105            Liver Cirrhosis, Biliary
# 1  MESH:D009369                           Neoplasms
# 2  MESH:D005892  Gingivitis, Necrotizing Ulcerative
# 3  MESH:D010020                       Osteonecrosis
# 4  MESH:D014522                   Urethral Diseases
#
#                                            other-ids  \
# 0  DO:DOID:12236|OMIM:109720|OMIM:614220|OMIM:614221
# 1                                        DO:DOID:162
# 2                         DO:DOID:13924|DO:DOID:9673
# 3                                      DO:DOID:10159
# 4                                        DO:DOID:732
#
#                                parent-ids  \
# 0               MESH:D002780|MESH:D008103
# 1                                  MESH:C
# 2  MESH:D005674|MESH:D005891|MESH:D007239
# 3               MESH:D001847|MESH:D009336
# 4                            MESH:D014570
#
#                                      disease-treenum  \
# 0  C06.130.120.135.250.250|C06.552.150.250|C06.55...
# 1                                                C04
# 2  C01.252.400.388.350.400|C01.539.424|C07.465.71...
# 3                        C05.116.852|C23.550.717.732
# 4                        C12.777.767|C13.351.968.767
#
#                                     disease-synonyms  \
# 0  Biliary Cirrhosis|Biliary Cirrhosis, Primary|B...
# 1  Benign Neoplasm|Benign Neoplasms|Cancer|Cancer...
# 2  Acute Membranous Gingivitides|Acute Membranous...
# 3  Aseptic Necrosis of Bone|Avascular Necrosis of...
# 4  Diseases, Urethral|Disease, Urethral|Urethral ...
#
#                                     disease-category
# 0                           Digestive system disease
# 1                                             Cancer
# 2       Bacterial infection or mycosis|Mouth disease
# 3        Musculoskeletal disease|Pathology (process)
# 4  Urogenital disease (female)|Urogenital disease...

# %%
df = df.where((pd.notnull(df)), None)

# Rename to match schema
df.rename(columns={
    'disease-id': 'disease_id',
    'disease-name': 'disease_name',
    'disease-category': 'disease_category',
    'disease-synonyms': 'disease_synonyms'
}, inplace=True)

# Keep only selected columns.
df = df[['disease_id', 'disease_name', 'disease_category']]

data_list= list(df.T.to_dict().values())

# %%
add_to_db(Disease, data_list)

# %% [markdown]
# ### Gene Lexicon

# %%
df = pd.read_csv('../data/version-3/gene-disease.tsv', sep='\t', encoding='utf-8')[['gene-id']]
df.drop_duplicates(subset=['gene-id'], inplace=True)
df.head()
# Out:
#    gene-id
# 0     1588
# 1    26504
# 2     9499
# 3    29940
# 4   113189

# %%
df.rename(columns={
    'gene-id': 'gene_id',
}, inplace=True)


data_list= list(df.T.to_dict().values())

# %%
add_to_db(Gene, data_list)

# %% [markdown]
# ### References

# %%
df = pd.read_csv(DATA/'publication-records.tsv', sep='\t', encoding='utf-8', index_col='Unnamed: 0')
clean_colnames(df)
df.head()
# Out:
#                                              authors          date  \
# 0  Elkiran T|Harputluoglu H|Yasar U|Babaoglu MO|D...  2007 Jan-Feb
# 1                       Severins N|Mensink RP|Plat J      2015 Feb
# 2  Li C|Zuo C|Deng G|Kuang R|Yang Q|Hu C|Sheng O|...          2013
# 3          Güneser S|Atici A|Cengizler I|Alparslan N  1996 May-Jun
# 4                                     Brvar M|Bunc M    2009 Sep 9
#
#                                         journal-name  \
# 0  Methods and findings in experimental and clini...
# 1  Nutrition, metabolism, and cardiovascular dise...
# 2                                           PloS one
# 3                   Allergologia et immunopathologia
# 4                                      Cases journal
#
#                journal-name-abbrv.      pmid  \
# 0  Methods Find Exp Clin Pharmacol  17344941
# 1        Nutr Metab Cardiovasc Dis  25456153
# 2                         PLoS One  23922960
# 3     Allergol Immunopathol (Madr)   8766742
# 4                          Cases J  19918387
#
#                               publication-type  \
# 0               Clinical Trial|Journal Article
# 1  Journal Article|Randomized Controlled Trial
# 2                              Journal Article
# 3                              Journal Article
# 4                              Journal Article
#
#                                                title
# 0  Differential alteration of drug-metabolizing e...
# 1  Effects of lutein-enriched egg yolk in butterm...
# 2  Contamination of bananas with beauvericin and ...
# 3  Inhalant allergens: as a cause of respiratory ...
# 4  High-degree atrioventricular block in acute et...

# %%
df = df.where((pd.notnull(df)), None)

df.rename(columns={
    'authors': 'authors',
    'journal-name': 'journal_name',
    'journal-name-abbrv.': 'journal_name_abbr',
    'publication-type':'publication_type',
},inplace=True)

data_list= list(df.T.to_dict().values())

# %%
add_to_db(References, data_list)

# %% [markdown]
# ### Chemicals

# %%
fchem = pd.read_csv(DATA/'food-chemical.tsv', sep='\t')
pubchems = set(fchem['pubchem-id'])

# %%
for i, item in enumerate(pubchems):
    db.session.add(Chemical(pubchem_id = item))

    if (i+1) % 10000 == 0:
        db.session.commit()
db.session.commit()

# %% [markdown]
# ## B. Associations

# %% [markdown]
# ### Food-disease

# %%
df = pd.read_csv(DATA/'food-disease.tsv', sep='\t', encoding='utf-8')
df = df.where((pd.notnull(df)), None)
df['association'] = df['association'].apply(str.lower)

df.head()
# Out:
#   association    disease-id         disease-term          food-id food-term  \
# 0    negative  MESH:D004487                edema    Plant ID:4045    Celery
# 1    negative  MESH:D014581            urticaria    Plant ID:4045    Celery
# 2    negative  MESH:D004487                edema    Plant ID:4043   parsley
# 3    negative  MESH:D014581            urticaria    Plant ID:4043   parsley
# 4    positive  MESH:D000544  Alzheimer's disease  Plant ID:136217  turmeric
#
#   food-type      pmid                                           sentence
# 0     Plant   7398283  |Celery| and parsley were confirmed as etiolog...
# 1     Plant   7398283  |Celery| and parsley were confirmed as etiolog...
# 2     Plant   7398283  Celery and |parsley| were confirmed as etiolog...
# 3     Plant   7398283  Celery and |parsley| were confirmed as etiolog...
# 4     Plant  24273069  Evidence suggests that curcumin, the phytochem...

# %%
df = df.groupby(['food-id', 'disease-id', 'association']).agg({
    'pmid': lambda s: '|'.join(str(e) for e in s),
})
df['type'] = 'Curated'
df['inference-network'] = ''

df.head()
# Out:
#                                                  pmid     type  \
# food-id            disease-id   association
# AlcoholicBev ID:17 MESH:D001523 positive      7195588  Curated
#                    MESH:D003866 positive      6798614  Curated
#                    MESH:D004487 negative     27873566  Curated
#                    MESH:D011041 negative     11639831  Curated
# AlcoholicBev ID:18 MESH:D001249 negative      6639863  Curated
#
#                                             inference-network
# food-id            disease-id   association
# AlcoholicBev ID:17 MESH:D001523 positive
#                    MESH:D003866 positive
#                    MESH:D004487 negative
#                    MESH:D011041 negative
# AlcoholicBev ID:18 MESH:D001249 negative

# %% [markdown]
# ### Gene-disease

# %%
df = pd.read_csv(DATA/'gene-disease.tsv', sep='\t', encoding='utf-8', index_col='Unnamed: 0')

df.rename(columns={
    'gene-id': 'gene_id',
    'disease-id': 'disease_id',
    'source': 'reference',
}, inplace=True)

df['type'] = 'Curated'
df['inference-network'] = ''

df.head()
# Out:
#         disease_id  gene_id                   reference     type  \
# 0  MESH:C000591739     1588                    ORPHANET  Curated
# 1  MESH:C000596385    26504                     UNIPROT  Curated
# 2  MESH:C000598645     9499  CTD_human;ORPHANET;UNIPROT  Curated
# 3  MESH:C000600608    29940                    ORPHANET  Curated
# 4  MESH:C000600608   113189  CTD_human;ORPHANET;UNIPROT  Curated
#
#   inference-network
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ###  Food-Gene

# %%
# Find food-gene associations
fd = pd.read_csv(DATA/'food-disease.tsv', sep='\t', encoding='utf-8')
gd = pd.read_csv(DATA/'gene-disease.tsv', sep='\t', encoding='utf-8')
food_gene = fd.merge(gd, on='disease-id').drop(['pmid', 'association', 'source'], axis=1)

# %%
food_gene = food_gene.drop_duplicates(subset=['food-id', 'gene-id', 'disease-id']).\
    groupby(['food-id', 'gene-id']).agg({
    'disease-id': lambda s: '|'.join(s)
})

food_gene['type'] = 'Inferred'
food_gene.rename(columns={'disease-id': 'inference-network'}, inplace=True)

food_gene.head()
# Out:
#                            inference-network      type
# food-id            gene-id
# AlcoholicBev ID:17 2            MESH:D003866  Inferred
#                    15           MESH:D003866  Inferred
#                    52           MESH:D003866  Inferred
#                    81           MESH:D004487  Inferred
#                    100          MESH:D004487  Inferred

# %% [markdown]
# ### Food-chemicals

# %%
df = pd.read_csv(DATA/'food-chemical.tsv', sep='\t', encoding='utf-8')
df['type'] = 'Curated'
df['inference-network'] = ''
df.head()
# Out:
#            food-id  pubchem-id                      content reference  \
# 0  Plant ID:100170     5280378  Detected but not quantified  KNApSAcK
# 1  Plant ID:100170    44260113  Detected but not quantified  KNApSAcK
# 2  Plant ID:100506        1150  Detected but not quantified  KNApSAcK
# 3  Plant ID:100506        5202  Detected but not quantified  KNApSAcK
# 4  Plant ID:100506     5372945  Detected but not quantified  KNApSAcK
#
#       type inference-network
# 0  Curated
# 1  Curated
# 2  Curated
# 3  Curated
# 4  Curated

# %% [markdown]
# ### Chemical-disease

# %%
cd = pd.read_csv(DATA/'chemical-disease.tsv', sep='\t', encoding='utf-8', index_col='Unnamed: 0')

# Drop marker/mechanism associations wherever therapeutic is available
cd = cd.sort_values('type', ascending=False).drop_duplicates(subset=['pubchem-id', 'disease-id'])

cd.rename(columns={
    'type': 'association',
}, inplace=True)

cd['reference'] = 'CTD'
cd['type'] = 'Inferred'
cd['inference-network'] = ''

cd.head()
# Out:
#        pubchem-id    disease-id  association reference      type  \
# 0         5280378  MESH:D002583  therapeutic       CTD  Inferred
# 56668        3776  MESH:D012772  therapeutic       CTD  Inferred
# 56396      688674  MESH:D009336  therapeutic       CTD  Inferred
# 56355         936  MESH:D003921  therapeutic       CTD  Inferred
# 56353         936  MESH:D012393  therapeutic       CTD  Inferred
#
#       inference-network
# 0
# 56668
# 56396
# 56355
# 56353
